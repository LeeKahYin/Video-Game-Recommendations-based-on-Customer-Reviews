# %%
# mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# read a file
gdrive_path = '/content/drive/MyDrive/mydata/'

# %%
pip install corextopic
# Out:
# Requirement already satisfied: corextopic in /usr/local/lib/python3.10/dist-packages (1.1)

# %%
import numpy as np
import scipy.sparse as ss
import pickle
from corextopic import corextopic as ct
from sklearn.feature_extraction.text import CountVectorizer
import pandas as pd
from ast import literal_eval

# %% [markdown]
# ## Aspect Extraction using CorEx

# %%
# read review dataset
data_anchored_corex = pd.read_csv(f'{gdrive_path}PlayStation_Game_Reviews_Cleaned.csv')

# read restructured aspects
train_topics = pd.read_excel(f'{gdrive_path}PS Game Extracted Topics.xlsx')

df_anchored_corex = pd.DataFrame()
data_words_anchored_corex = []
for x in data_anchored_corex['Clean']:
    data_words_anchored_corex.append(' '.join(literal_eval(x)))

keywords = []
for x in train_topics['Keys']:
    keywords.append(literal_eval(x))

# %%
vectorizer_anchored_corex = CountVectorizer(stop_words='english', max_features=20000, binary=True)

doc_word_anchored_corex = vectorizer_anchored_corex.fit_transform(data_words_anchored_corex)
doc_word_anchored_corex = ss.csr_matrix(doc_word_anchored_corex)

words = list(np.asarray(vectorizer_anchored_corex.get_feature_names_out()))

# %%
#Train the CorEx topic model with 6 topics
topic_model_anchored_corex = ct.Corex(n_hidden=6, words=words, max_iter=1000, verbose=False, seed=2022)
topic_model_anchored_corex.fit(doc_word_anchored_corex, words=words, anchors = keywords, anchor_strength=3);

#Save the model and topics
pickle.dump(topic_model_anchored_corex, open(f'{gdrive_path}Assignment 1/CorEx_Model/Anchored_CorEx_Train_model.sav', 'wb'))
topic_list_anchored_corex = topic_model_anchored_corex.get_topics()

# %%
df_anchored_corex['Topics'] = topic_list_anchored_corex
df_anchored_corex.to_excel(f'{gdrive_path}Assignment 1/CorEx_Model/Anchored_CorEx_Topics.xlsx')

# %%
# Print all topics from the CorEx topic model
anchored_corex_topics = topic_model_anchored_corex.get_topics()
for n,topic in enumerate(anchored_corex_topics):
    topic_words,_,_ = zip(*topic)
    print('{}: '.format(n) + ', '.join(topic_words))
# Out:
# 0: story, character, action, combat, soul, mission, war, boss, fighting, dark
# 1: great, good, fun, love, amazing, awesome, game, enjoy, entertain, exciting
# 2: excellent, easy, perfect, difficult, incredible, repetitive, solid, smooth, bug, replay
# 3: buy, recommend, worth, price, money, highly, value, definitely, sale, cost
# 4: world, open, music, soundtrack, make, feel, player, enemy, level, little
# 5: graphic, pretty, beautiful, visual, stunning, wonderful, scene, cinematic, gameplay, compelling

# %% [markdown]
# ## Label PlayStation Game Review Using CorEx

# %%
data = pd.read_csv(f'{gdrive_path}PlayStation_Game_Reviews_Cleaned.csv')

aspect_list = [[],[],[],[],[],[]]
words_set = []
for x in data['Clean']:
    words_set.append(set(literal_eval(x)))

model = pickle.load(open(f'{gdrive_path}Assignment 1/CorEx_Model/Anchored_CorEx_Train_model.sav', 'rb'))
topic_list = []
for i, topic_words in enumerate(model.get_topics()):
  topic_list.append(set([words[0] for words in topic_words if words[1] > 0]))

for words in words_set:
  for i,topic_words in enumerate(topic_list):
      if (words & topic_words):
        aspect_list[i].append(1)
      else :
        aspect_list[i].append(0)

for i in range(6):
  data['Topic ' + str(i)] = aspect_list[i]

data.to_excel(f'{gdrive_path}Assignment 1/PlayStation_Game_Reviews_Labelled_Aspect.xlsx', index=False)

# %% [markdown]
# ## Sentiment Analysis using BiLSTM-Skip Gram

# %%
from keras.models import load_model
from tensorflow.keras.preprocessing.sequence import pad_sequences

# Load biLSTM model from the file
loaded_model = load_model(f'{gdrive_path}Assignment 1/Sentiment_bilstm_skipgram.sav')

# Load tokenizer
loaded_tokenizer = pickle.load(open(f'{gdrive_path}Assignment 1/lstm_w2v_tokenizer.pkl', 'rb'))

# %%
review_sentence = data['review'].astype(str).values

loaded_tokenizer.fit_on_texts(data.review.astype(str))
padded_text = pad_sequences(loaded_tokenizer.texts_to_sequences(review_sentence), maxlen=300)

# %%
score = loaded_model.predict(padded_text)
# Out:
# 3765/3765 [==============================] - 333s 88ms/step

# %%
label = []
for s in score:
  if s < 0.5:
    label.append('negative')
  else:
    label.append('positive')

data['Score'] = score
data['Sentiment'] = label

data
# Out:
#         review_id                                    product  \
# 0               0  Assassin's Creed Origins Standard Edition
# 1               0  Assassin's Creed Origins Standard Edition
# 2               1  Assassin's Creed Origins Standard Edition
# 3               1  Assassin's Creed Origins Standard Edition
# 4               2  Assassin's Creed Origins Standard Edition
# ...           ...                                        ...
# 120470      52446               Tony Hawk's Pro Skater 1 + 2
# 120471      52446               Tony Hawk's Pro Skater 1 + 2
# 120472      52446               Tony Hawk's Pro Skater 1 + 2
# 120473      52446               Tony Hawk's Pro Skater 1 + 2
# 120474      52447               Tony Hawk's Pro Skater 1 + 2
#
#                                                    review  \
# 0        it's a great game for who likes a single player.
# 1       uncountables missions and come back the old st...
# 2       i ordered a new copy and received a previously...
# 3                     the plastic of the case was broken.
# 4                   i have lots of fun playing this game.
# ...                                                   ...
# 120470  accepting the steep learning curve, i would de...
# 120471  others can probably give more details about ho...
# 120472                             i can't speak to that.
# 120473  what i can say is that as a person who always ...
# 120474  great trip down memory lane with updated graph...
#
#                                                     Clean  Topic 0  Topic 1  \
# 0           ['great', 'game', 'like', 'single', 'player']        0        1
# 1       ['uncountable', 'mission', 'come', 'back', 'ol...        1        0
# 2       ['order', 'new', 'copy', 'receive', 'previousl...        0        0
# 3                            ['plastic', 'case', 'break']        0        0
# 4                       ['lot', 'fun', 'playing', 'game']        0        1
# ...                                                   ...      ...      ...
# 120470  ['accept', 'steep', 'learning', 'curve', 'defi...        0        1
# 120471  ['other', 'probably', 'give', 'detail', 'eleme...        0        1
# 120472                                          ['speak']        0        0
# 120473  ['say', 'person', 'always', 'pass', 'interest'...        0        1
# 120474  ['great', 'trip', 'memory', 'lane', 'update', ...        0        1
#
#         Topic 2  Topic 3  Topic 4  Topic 5     Score Sentiment
# 0             0        0        1        0  0.705584  positive
# 1             0        0        0        0  0.331598  negative
# 2             0        0        1        0  0.257791  negative
# 3             0        0        0        0  0.341962  negative
# 4             0        0        0        0  0.331739  negative
# ...         ...      ...      ...      ...       ...       ...
# 120470        0        1        0        0  0.441534  negative
# 120471        0        0        0        0  0.346834  negative
# 120472        0        0        0        0  0.265817  negative
# 120473        0        0        0        0  0.075322  negative
# 120474        0        0        0        1  0.446140  negative
#
# [120475 rows x 12 columns]

# %%
data.to_excel(f'{gdrive_path}Assignment 1/PlayStation_Game_Reviews_Final.xlsx', index=False)

# %% [markdown]
# ## Rank Top 5 Products With Highest Positive Sentiment for Each Topic

# %%
# dropping rows with sentiment being negative
data.drop(data[data['Sentiment'] == 'negative'].index, inplace=True)

# %%
topics = ['Topic 0', 'Topic 1', 'Topic 2', 'Topic 3', 'Topic 4', 'Topic 5']

for topic in topics:
    data[topic] = data[topic] * data['Score']

# %%
# Group by 'product' and calculate the mean sentiment values for each topic
sentiment_topics = data.groupby('product')[['Topic 0', 'Topic 1', 'Topic 2', 'Topic 3', 'Topic 4', 'Topic 5']].mean().reset_index()

# Rename columns
column_mapping = {'product': 'PlayStation Game',
                  'Topic 0': 'Genres',
                  'Topic 1': 'Mood',
                  'Topic 2': 'Game Experience',
                  'Topic 3': 'Price',
                  'Topic 4': 'Soundtrack',
                  'Topic 5': 'Graphics'}

sentiment_topics = sentiment_topics.rename(columns=column_mapping)
sentiment_topics
# Out:
#                                      PlayStation Game    Genres      Mood  \
# 0           Assassin's Creed Origins Standard Edition  0.128742  0.442413
# 1            Batman-Return to Arkham Standard Edition  0.079191  0.438686
# 2    Call of Duty-Black Ops Cold War Standard Edition  0.065884  0.429765
# 3     Call of Duty-Modern Warfare II Standard Edition  0.068386  0.426535
# 4                       DOOM Eternal Standard Edition  0.109752  0.407997
# 5               DRAGON BALL FighterZ Standard Edition  0.143866  0.482066
# 6                                           Days Gone  0.161514  0.460581
# 7                    Death Stranding Standard Edition  0.164726  0.415096
# 8                      Demon's Souls Standard Edition  0.098845  0.434421
# 9                         Elden Ring Standard Edition  0.130373  0.431380
# 10                         Far Cry 6 Standard Edition  0.125696  0.430398
# 11                 Final Fantasy XVI Standard Edition  0.267547  0.411080
# 12                   Ghost of Tsushima Director's Cut  0.168318  0.446232
# 13         God of War III Remastered Standard Edition  0.105609  0.435573
# 14                 Grand Theft Auto V Premium Edition  0.061771  0.451272
# 15                   Hogwarts Legacy Standard Edition  0.104683  0.443087
# 16              Horizon Forbidden West Launch Edition  0.143843  0.462816
# 17                                Little Big Planet 3  0.035515  0.499777
# 18                                  Marvel's Avengers  0.168345  0.469388
# 19       Marvel's Spider-Man Game of the Year Edition  0.119564  0.480873
# 20  Marvel's Spider-Man Miles Morales Standard Lau...  0.127176  0.477946
# 21                  Mortal Kombat 11 Standard Edition  0.159114  0.456495
# 22                                   Mortal Kombat XL  0.140700  0.442179
# 23             Resident Evil Village Standard Edition  0.125221  0.418048
# 24                   Sackboy-A Big Adventure Standard  0.022610  0.492531
# 25  Sekiro-Shadows Die Twice Game of the Year Edition  0.175976  0.427190
# 26  South Park-The Fractured But Whole Standard Ed...  0.099584  0.418026
# 27                            Spyro Reignited Trilogy  0.010121  0.430861
# 28           Star Wars Jedi-Survivor Standard Edition  0.222862  0.443469
# 29    Tom Clancy's Rainbow Six Siege Standard Edition  0.052235  0.446745
# 30                       Tony Hawk's Pro Skater 1 + 2  0.010255  0.415150
#
#     Game Experience     Price  Soundtrack  Graphics
# 0          0.040628  0.050935    0.088607  0.105529
# 1          0.044327  0.089264    0.044810  0.100866
# 2          0.040979  0.053145    0.067773  0.103880
# 3          0.043776  0.056888    0.055975  0.098342
# 4          0.054125  0.052884    0.118373  0.086114
# 5          0.075896  0.061822    0.066765  0.100645
# 6          0.057766  0.058198    0.108703  0.109279
# 7          0.032409  0.067648    0.109477  0.137443
# 8          0.065715  0.066837    0.077079  0.132813
# 9          0.057593  0.057623    0.135585  0.073487
# 10         0.053074  0.088918    0.070211  0.107463
# 11         0.055296  0.055322    0.100049  0.128372
# 12         0.059452  0.069606    0.081902  0.185704
# 13         0.045993  0.092016    0.046075  0.112300
# 14         0.030461  0.109032    0.042332  0.050125
# 15         0.051395  0.049256    0.116986  0.093503
# 16         0.054584  0.057545    0.073739  0.179017
# 17         0.038737  0.061758    0.113843  0.033622
# 18         0.067684  0.065115    0.081085  0.099634
# 19         0.051171  0.087324    0.060980  0.104855
# 20         0.061470  0.061078    0.059286  0.161764
# 21         0.037358  0.067510    0.049107  0.131667
# 22         0.034564  0.085924    0.042716  0.091711
# 23         0.042225  0.079342    0.064389  0.099567
# 24         0.055779  0.067266    0.123315  0.075792
# 25         0.067824  0.058536    0.106678  0.085606
# 26         0.035714  0.062164    0.067499  0.042521
# 27         0.047987  0.054999    0.061439  0.099509
# 28         0.065616  0.051015    0.075877  0.115105
# 29         0.034983  0.068263    0.076537  0.068105
# 30         0.047864  0.058783    0.118600  0.069034

# %%
labelled_topics = ['Genres', 'Mood', 'Game Experience', 'Price', 'Soundtrack', 'Graphics']
result_df = pd.DataFrame()
for t in labelled_topics:
    # Find the 5 largest values in the specified column
    top_5_products = sentiment_topics.nlargest(5, t).reset_index()

    result_df[f'Top 5 based on {t}'] = top_5_products['PlayStation Game']

result_df
# Out:
#                                Top 5 based on Genres  \
# 0                 Final Fantasy XVI Standard Edition
# 1           Star Wars Jedi-Survivor Standard Edition
# 2  Sekiro-Shadows Die Twice Game of the Year Edition
# 3                                  Marvel's Avengers
# 4                   Ghost of Tsushima Director's Cut
#
#                                  Top 5 based on Mood  \
# 0                                Little Big Planet 3
# 1                   Sackboy-A Big Adventure Standard
# 2              DRAGON BALL FighterZ Standard Edition
# 3       Marvel's Spider-Man Game of the Year Edition
# 4  Marvel's Spider-Man Miles Morales Standard Lau...
#
#                       Top 5 based on Game Experience  \
# 0              DRAGON BALL FighterZ Standard Edition
# 1  Sekiro-Shadows Die Twice Game of the Year Edition
# 2                                  Marvel's Avengers
# 3                     Demon's Souls Standard Edition
# 4           Star Wars Jedi-Survivor Standard Edition
#
#                            Top 5 based on Price  \
# 0            Grand Theft Auto V Premium Edition
# 1    God of War III Remastered Standard Edition
# 2      Batman-Return to Arkham Standard Edition
# 3                    Far Cry 6 Standard Edition
# 4  Marvel's Spider-Man Game of the Year Edition
#
#           Top 5 based on Soundtrack  \
# 0       Elden Ring Standard Edition
# 1  Sackboy-A Big Adventure Standard
# 2      Tony Hawk's Pro Skater 1 + 2
# 3     DOOM Eternal Standard Edition
# 4  Hogwarts Legacy Standard Edition
#
#                              Top 5 based on Graphics
# 0                   Ghost of Tsushima Director's Cut
# 1              Horizon Forbidden West Launch Edition
# 2  Marvel's Spider-Man Miles Morales Standard Lau...
# 3                   Death Stranding Standard Edition
# 4                     Demon's Souls Standard Edition

# %%
result_df.to_excel(f'{gdrive_path}Assignment 1/PlayStation_Game_Top_5.xlsx', index=False)
